# %% [markdown]
# ### Getting data from petfinder api and saving in json file - Jagrati

# %%
# Importing needed Libraries
import pandas as pd
from sqlalchemy import create_engine
import pymongo
import json
from bson import json_util, ObjectId

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
#conn = 'mongodb+srv://TeamCatViz:RockingTeam#1@cluster0.ddihz.mongodb.net/petfinder_db?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# %%
# # Retrieve the first 100 records from the MongoDB collection for testing
db = client.petfinder_db
austin_pets_coll = db.austin_pet_data.find(limit=100)
pets_coll = db.tx_pet_data.find(limit=100)
# # Convert PyMongo cursor to json string
#pets_json = json.loads(json_util.dumps(pets_coll))
#pets_json

# %%
# Query Parameters
params = {
    "type" : {"$eq" : "Dog"},
    "breeds.primary" : {"$eq" : "Chihuahua"},
    "colors.primary" : {"$in" : ["Bicolor"]}
}

# %%
fields = {"_id":0
                ,"type":1
                ,"breeds.primary":1
                ,"primary_photo_cropped.small":1
            }

# %%
# # Retrieve the first 100 records from the MongoDB collection for testing
#db = client.petfinder_db
db = client.pet_db
#austin_pets_coll = db.austin_pet_data.find(params)
#pets_coll = db.tx_pet_data.find(params)
pets_coll = db.pet_data.find(params)
# # Convert PyMongo cursor to json string
#pets_json = json.loads(json_util.dumps(pets_coll))
#pets_json

# %%
pets_coll

# %%
austin_data_df = pd.DataFrame(list(austin_pets_coll))
petfinder_data_df = pd.DataFrame(list(pets_coll))

# %%
petfinder_data_df = pd.DataFrame(list(pets_coll))

# %%
petfinder_data_df.count()
# Out:
# _id                       21
# id                        21
# organization_id           21
# url                       21
# type                      21
# species                   21
# breeds                    21
# colors                    21
# age                       21
# gender                    21
# size                      21
# coat                      19
# attributes                21
# environment               21
# tags                      21
# name                      21
# description               21
# organization_animal_id     4
# photos                    21
# primary_photo_cropped     20
# videos                    21
# status                    21
# status_changed_at         21
# published_at              21
# distance                  21
# contact                   21
# _links                    21
# dtype: int64

# %%
austin_data_df.head()
# Out:
#                         _id  Animal ID  Name             DateTime  \
# 0  60321a7ab7fff2f8c0e17d0a     829664  None  2021-02-20 09:34:00
# 1  60321a7ab7fff2f8c0e17d0b     829662  None  2021-02-20 08:17:00
# 2  60321a7ab7fff2f8c0e17d0c     829661  None  2021-02-19 17:23:00
# 3  60321a7ab7fff2f8c0e17d0d     829660  None  2021-02-19 16:43:00
# 4  60321a7ab7fff2f8c0e17d0e     829659  None  2021-02-19 16:43:00
#
#                        Found Location    Intake Type Intake Condition  \
# 0            Del Valle in Austin (TX)          Stray          Injured
# 1   406 Chaparral Road in Austin (TX)  Public Assist           Normal
# 2    9604 Carson Creek in Austin (TX)          Stray           Normal
# 3  14204 Jacobson Road in Austin (TX)          Stray           Normal
# 4  14204 Jacobson Road in Austin (TX)          Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  ...                 Color  \
# ...

# %%
petfinder_data_df.head()
# Out:
#                         _id        id organization_id  \
# 0  6032005d31cc845e2b916ec7  50614898          TX2184
# 1  6032005d31cc845e2b916ec8  50614755          TX2184
# 2  6032005d31cc845e2b916ec9  50614759           TX487
# 3  6032005d31cc845e2b916eca  50614756           TX236
# 4  6032005d31cc845e2b916ecb  50614729          TX1888
#
#                                                  url type species  \
# 0  https://www.petfinder.com/dog/simon-50614898/t...  Dog     Dog
# 1  https://www.petfinder.com/dog/scout-50614755/t...  Dog     Dog
# 2  https://www.petfinder.com/dog/a596096-50614759...  Dog     Dog
# 3  https://www.petfinder.com/dog/1114909-50614756...  Dog     Dog
# 4  https://www.petfinder.com/dog/june-jum-star-50...  Dog     Dog
#
#                                               breeds  \
# 0  {'primary': 'Chihuahua', 'secondary': None, 'm...
# 1  {'primary': 'Collie', 'secondary': 'Chihuahua'...
# 2  {'primary': 'Parson Russell Terrier', 'seconda...
# ...

# %%
petfinder_data_df["type"].unique()
# Out:
# array(['Dog'], dtype=object)
